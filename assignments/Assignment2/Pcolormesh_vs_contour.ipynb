# %% [markdown]
# ### comparing contourf to pcolormesh

# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import make_moons

# %%
from matplotlib.colors import ListedColormap

cmap_light = ListedColormap(['#BBBBBB', '#BBFFBB'])
cmap_bold = ListedColormap(['#000000', '#00FF00'])

# %%
X, y = make_moons(n_samples=1000, noise=0.35)

clf = KNeighborsClassifier(n_neighbors=5)
clf = clf.fit(X, y)

# %%
h = .5 # set granularity of meshgrid ( used for area shading)

x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1

xx, yy = np.meshgrid(np.arange(x1_min, x1_max, h),
                     np.arange(x2_min, x2_max, h))

Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# %%
fig, ax = plt.subplots(figsize=(16, 12))

ax.contourf(xx, yy, Z) # draw decision boundary

# ax.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold, edgecolor='k', s=20)
ax.set_xlim(xx.min(), xx.max())
ax.set_ylim(yy.min(), yy.max())
ax.set_title('contourf plot', fontsize=20)
ax.set_xlabel('feature 1')
ax.set_ylabel('feature 2')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 12))

ax.pcolormesh(xx, yy, Z) # draw decision boundary

# ax.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold, edgecolor='k', s=20)
ax.set_xlim(xx.min(), xx.max())
ax.set_ylim(yy.min(), yy.max())
ax.set_title('pcolormesh plot', fontsize=20)
ax.set_xlabel('feature 1')
ax.set_ylabel('feature 2')

plt.show()
